# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# show all columns
pd.set_option('display.max_columns', None)

# %%
# Load the real and fake datasets
real = pd.read_csv('data/True.csv')
fake = pd.read_csv('data/Fake.csv')

# Add labels
real['label'] = 1
fake['label'] = 0

# Combine them together
data = pd.concat([real, fake]).sample(frac=1).reset_index(drop=True)

data.head()
# Out:
#                                                title  \
# 0  Senior Russian diplomat hails U.S. readiness t...
# 1  Gay activists march through Serb capital behin...
# 2  Kurdish officials say thousands flee Kirkuk si...
# 3   Ken Burns Destroys Trump For Lying ‘200 Or 30...
# 4  Britain accelerates Brexit plans, divorce talk...
#
#                                                 text    subject  \
# 0  MOSCOW (Reuters) - Russia welcomes U.S. Secret...  worldnews
# 1  BELGRADE (Reuters) - Serbian gay right activis...  worldnews
# 2  BAGHDAD (Reuters) - Kurdish officials said on ...  worldnews
# 3  Documentary filmmaker Ken Burns knows a thing ...       News
# 4  LONDON/BRATISLAVA (Reuters) - Britain is accel...  worldnews
#
#                   date  label
# 0   December 13, 2017       1
# 1  September 17, 2017       1
# 2    October 19, 2017       1
# 3       August 1, 2016      0
# 4    October 31, 2017       1

# %%
# Save cleaned data
data.to_csv('data/cleaned_data.csv', index=False)
print("✅ Cleaned dataset saved successfully at data/cleaned_data.csv")
# Out:
# ✅ Cleaned dataset saved successfully at data/cleaned_data.csv

# %%
sns.countplot(x='label', data=data)
plt.title('Distribution of Real vs Fake News')
plt.xlabel('Label (1 = Real, 0 = Fake)')
plt.ylabel('Count')
plt.show()

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44898 entries, 0 to 44897
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    44898 non-null  object
#  1   text     44898 non-null  object
#  2   subject  44898 non-null  object
#  3   date     44898 non-null  object
#  4   label    44898 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 1.7+ MB
#               label
# count  44898.000000
# mean       0.477015
# std        0.499477
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
sns.countplot(x='label', data=data)
plt.title('Distribution of Real vs Fake News')
plt.show()

# %%
print("Real News Example:\n")
print(data[data['label']==1]['text'].iloc[0][:500])

print("\nFake News Example:\n")
print(data[data['label']==0]['text'].iloc[0][:500])
# Out:
# Real News Example:
#
# MOSCOW (Reuters) - Russia welcomes U.S. Secretary of State Rex Tillerson s statement that Washington is ready to begin direct talks with North Korea, the Interfax news agency cited Russian Deputy Foreign Minister Sergei Ryabkov as saying on Wednesday. Tillerson said direct talks with Pyongyang might start  without pre-conditions, backing away from a key U.S. demand that North Korea must first accept that giving up its nuclear arsenal would be part of any negotiations.
#
# Fake News Example:
#
# Documentary filmmaker Ken Burns knows a thing or two about presidential decorum. He has made documentaries on Thomas Jefferson, Theodore Roosevelt and Franklin Roosevelt. He s also an accomplished student of history, which means that when he says Donald Trump isn t presidential, Americans should stand up and take notice.Burns appeared on Morning Joe on Monday morning. He was asked if Trump was the least qualified major party candidate since _____.Burns answered that there s never been anyone les

# %%
data.to_csv('data/cleaned_data.csv', index=False)
print("✅ Cleaned data saved to data/cleaned_data.csv")
# Out:
# ✅ Cleaned data saved to data/cleaned_data.csv
